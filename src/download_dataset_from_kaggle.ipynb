# %%
# !pwd
# Out:
# /home/midori/Desktop/NLP/src

# %%
#!/bin/bash
# !kaggle datasets download lakshmi25npathi/imdb-dataset-of-50k-movie-reviews -p ../Data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# License(s): other
# ...
# 100%|██████████████████████████████████████| 25.7M/25.7M [00:11<00:00, 2.32MB/s]

# %%
# extracting zip file in the /Data directory
from zipfile import ZipFile
from pathlib import Path

zippath = "../Data/imdb-dataset-of-50k-movie-reviews.zip"
extractpath = "../Data/raw_imdb_reviews"

# %%
with ZipFile(zippath,'r') as ref:
    ref.extractall(extractpath)
